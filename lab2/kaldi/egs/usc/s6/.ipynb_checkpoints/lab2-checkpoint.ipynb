# %%
# !./Steps_3_4.1.py

# %%
# !./Step_4.2.1.py

# %%
# !./Steps_4.2.2-5.sh
# Out:
# ./Steps_4.2.2-5.sh: 18: [: unexpected operator
# LOGFILE:/dev/null
# $bin/ngt -i="$inpfile" -n=$order -gooout=y -o="$gzip -c > $tmpdir/ngram.${sdict}.gz" -fd="$tmpdir/$sdict" $dictionary $additional_parameters >> $logfile 2>&1
# $scr/build-sublm.pl $verbose $prune $prune_thr_str $smoothing "$additional_smoothing_parameters" --size $order --ngrams "$gunzip -c $tmpdir/ngram.${sdict}.gz" -sublm $tmpdir/lm.$sdict $additional_parameters >> $logfile 2>&1
# LOGFILE:/dev/null
# $bin/ngt -i="$inpfile" -n=$order -gooout=y -o="$gzip -c > $tmpdir/ngram.${sdict}.gz" -fd="$tmpdir/$sdict" $dictionary $additional_parameters >> $logfile 2>&1
# $scr/build-sublm.pl $verbose $prune $prune_thr_str $smoothing "$additional_smoothing_parameters" --size $order --ngrams "$gunzip -c $tmpdir/ngram.${sdict}.gz" -sublm $tmpdir/lm.$sdict $additional_parameters >> $logfile 2>&1
# inpfile: data/local/lm_tmp/lm_train_unigram.ilm.gz
# outfile: /dev/stdout
# loading up to the LM level 1000 (if any)
# dub: 10000000
# ...

# %%
# !./4.2_Q1-Calculate_perplexity.sh
# Out:
# --------------------------------------
# Calculate Perplexity of dev_unigram lm
# --------------------------------------
# inpfile: data/local/lm_tmp/lm_train_unigram.ilm.gz
# outfile: lm_train_unigram.ilm.blm
# evalfile: ./data/local/dict/lm_dev.text
# loading up to the LM level 1000 (if any)
# dub: 10000000
# OOV code is 1510
# OOV code is 1510
# Start Eval
# OOV code: 1510
# --------------------------------------
# Calculate Perplexity of dev_bigram lm
# --------------------------------------
# inpfile: data/local/lm_tmp/lm_train_bigram.ilm.gz
# outfile: lm_train_bigram.ilm.blm
# evalfile: ./data/local/dict/lm_dev.text
# loading up to the LM level 1000 (if any)
# dub: 10000000
# OOV code is 1510
# OOV code is 1510
# Start Eval
# OOV code: 1510
# --------------------------------------
# Calculate Perplexity of test_unigram lm
# --------------------------------------
# inpfile: data/local/lm_tmp/lm_train_unigram.ilm.gz
# outfile: lm_train_unigram.ilm.blm
# ...

# %%
# !./Step_4.3.sh
# Out:
# ./Step_4.3.sh: 18: [: unexpected operator
# ./utils/fix_data_dir.sh: file ./data/train/utt2spk is not in sorted order or not unique, sorting it
# ./utils/fix_data_dir.sh: file ./data/train/text is not in sorted order or not unique, sorting it
# ./utils/fix_data_dir.sh: file ./data/train/wav.scp is not in sorted order or not unique, sorting it
# fix_data_dir.sh: kept all 1468 utterances.
# fix_data_dir.sh: old files are kept in ./data/train/.backup
# ./utils/fix_data_dir.sh: file ./data/test/utt2spk is not in sorted order or not unique, sorting it
# ./utils/fix_data_dir.sh: file ./data/test/text is not in sorted order or not unique, sorting it
# ./utils/fix_data_dir.sh: file ./data/test/wav.scp is not in sorted order or not unique, sorting it
# fix_data_dir.sh: kept all 184 utterances.
# fix_data_dir.sh: old files are kept in ./data/test/.backup
# fix_data_dir.sh: kept all 183 utterances.
# fix_data_dir.sh: old files are kept in ./data/dev/.backup
# --------------------------------
# ...

# %%
# !./4.3_Q3-Extract_dim_frames.sh
# Out:
# feat-to-dim ark:./mfcc_train/raw_mfcc_train.1.ark -
# 13
# feat-to-len ark:./mfcc_train/raw_mfcc_train.1.ark ark,t:data/train/feats.lengths
# f1-usctimit-ema--184 237
# f1-usctimit-ema--185 377
# f1-usctimit-ema--186 317
# f1-usctimit-ema--187 399
# f1-usctimit-ema--188 338

# %%
# !./Step_4.4.sh
# Out:
# ./Step_4.4.sh: 18: [: unexpected operator
# -----------------------------------
# Train Monophones
# -----------------------------------
# ./steps/train_mono.sh --boost-silence 1.25 --cmd run.pl ./data/train ./data/lang_test ./exp/mono
# ./steps/train_mono.sh: Initializing monophone system.
# ./steps/train_mono.sh: Compiling training graphs
# ./steps/train_mono.sh: Aligning data equally (pass 0)
# ./steps/train_mono.sh: Pass 1
# ./steps/train_mono.sh: Aligning data
# ./steps/train_mono.sh: Pass 2
# ./steps/train_mono.sh: Aligning data
# ./steps/train_mono.sh: Pass 3
# ./steps/train_mono.sh: Aligning data
# ./steps/train_mono.sh: Pass 4
# ./steps/train_mono.sh: Aligning data
# ./steps/train_mono.sh: Pass 5
# ./steps/train_mono.sh: Aligning data
# ./steps/train_mono.sh: Pass 6
# ./steps/train_mono.sh: Aligning data
# ./steps/train_mono.sh: Pass 7
# ./steps/train_mono.sh: Aligning data
# ./steps/train_mono.sh: Pass 8
# ./steps/train_mono.sh: Aligning data
# ...
